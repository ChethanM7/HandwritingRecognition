# %%
# !python main.py
# Out:
# Training character error rate of the model: 8.654728%
# Training Accuracy: 91.345272%
# Python: 3.9.5 (tags/v3.9.5:0a7dcbd, May  3 2021, 17:27:52) [MSC v.1928 64 bit (AMD64)]
# Tensorflow: 2.6.0-dev20210616
# Init with stored values from ../model/snapshot-24
#
#
#
#
#
#
#
#
#
# 			HANDWRITTEN TEXT RECOGNITION
#
#
#
#
#
#
# DIGITAL TEXT: Clothed leat by leaf with the disappoisthet
# AUTOCORRECT : Clothes left by leaf with the disappoisthet
# 2021-10-02 09:37:02.685500: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-10-02 09:37:02.685538: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# ...

# %%
# !python main.py --validate
# Out:
# Warning, damaged images found: []
# Damaged images expected: ['a01-117-05-02.png', 'r06-022-03-05.png']
# Train: 12685, Validation: 668
# Python: 3.9.5 (tags/v3.9.5:0a7dcbd, May  3 2021, 17:27:52) [MSC v.1928 64 bit (AMD64)]
# Tensorflow: 2.6.0-dev20210616
# Init with stored values from ../model/snapshot-24
# Validate neural network
# Batch: 1 / 66
# Ground truth -> Recognized
# [ERR:8] "to have an open quarrel" -> "to har an ope arne n"
# [ERR:14] "any minute , and she knew it ." -> "Iimte ,an she ue i."
# [OK] "Almost in desperation she appealed , " Will you meet" -> "Almost in desperation she appealed , " Will you meet"
# [ERR:7] "me at the gate , four o'clock tomorrow ? " " Why ? " he" -> "mne at the gate , four oclock tomorow? " " why?" he"
# [ERR:4] "enquired , combing his thick , tawny hair . " To bring" -> "exguired , cembing his thick , tawny hair , " To bring"
# ...
